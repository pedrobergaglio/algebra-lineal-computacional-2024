# %%
import matplotlib.pyplot as plt
import time 
from funciones import *

def medir_tiempo_ejecucion(W, p):
    start_time = time.time()
    calcularRanking(W, p)
    end_time = time.time()
    return end_time - start_time

    
# pongo todos los grafos juntos 
archivos_grafos = ['./tests/test_aleatorio.txt','./tests/mathworld_grafo.txt' , './tests/test_dosestrellas.txt', './tests/instagram_famosos_grafo.txt', './tests/test_30_segundos.txt']  # Reemplaza con los nombres de tus archivos de grafo
parametro_p = 0.85 

# me armo lista svacias para pondes despues lo datos que me genere y asi poder graficarlos 
ranking_ejecucion = []
tamanos_grafos = []

for archivo_grafo in archivos_grafos:
    
    W = leer_archivo(archivo_grafo)
    
    x = medir_tiempo_ejecucion(W, parametro_p)
    
    ranking_ejecucion.append(x)
    tamanos_grafos.append(W.shape[0]) 

# armo este quilombo de plts jajaja para graficar los tiempos y grafos 
plt.figure(figsize=(10, 6))
plt.plot(tamanos_grafos, ranking_ejecucion, marker='o', linestyle='-')
plt.title('Tiempos de ejecución de PageRank en función del tamaño del grafo')
plt.xlabel('Tamaño del grafo (número de nodos)')
plt.ylabel('Tiempo de ejecución (segundos)')
plt.grid(True)
plt.show()

# %%
for archivo_grafo in archivos_grafos:
    
    W = leer_archivo(archivo_grafo)
    
    #tiempo = medir_tiempo_ejecucion(W, parametro_p)
    
    #tiempos_ejecucion.append(tiempo)
    #tamanos_grafos.append(W.shape[0]) 

    print(archivo_grafo, W.shape[0])
# Out:
# ./tests/test_aleatorio.txt 5
# ./tests/mathworld_grafo.txt 10
# ./tests/test_dosestrellas.txt 12
# ./tests/instagram_famosos_grafo.txt 30
# ./tests/test_30_segundos.txt 3000

# %%
import matplotlib.pyplot as plt
import time 
from funciones import *

def medir_tiempo_ejecucion(W, p):
    start_time = time.time()
    calcularRanking(W, p)
    end_time = time.time()
    return end_time - start_time

    
# pongo todos los grafos juntos 
archivos_grafos = ['./tests/test_aleatorio.txt','./tests/mathworld_grafo.txt' , './tests/test_dosestrellas.txt', './tests/instagram_famosos_grafo.txt', './tests/test_30_segundos.txt']  # Reemplaza con los nombres de tus archivos de grafo
parametro_p = 0.85 

# me armo lista svacias para pondes despues lo datos que me genere y asi poder graficarlos 
ranking_ejecucion = []
tamanos_grafos = []

for archivo_grafo in archivos_grafos:
    
    W = leer_archivo(archivo_grafo)
    
    x = medir_tiempo_ejecucion(W, parametro_p)
    
    ranking_ejecucion.append(x)
    tamanos_grafos.append(W.shape[0]) 

# armo este quilombo de plts jajaja para graficar los tiempos y grafos 
plt.figure(figsize=(10, 6))
plt.semilogy(tamanos_grafos, ranking_ejecucion, marker='o', linestyle='-')
plt.title('Tiempos de ejecución de PageRank en función del tamaño del grafo')
plt.xlabel('Tamaño del grafo (número de nodos)')
plt.ylabel('Tiempo de ejecución (segundos)')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import time 
from funciones import *

def medir_tiempo_ejecucion(W, p):
    start_time = time.time()
    calcularRanking(W, p)
    end_time = time.time()
    return end_time - start_time

    
# pongo todos los grafos juntos 
archivos_grafos = ['./tests/test_aleatorio.txt','./tests/mathworld_grafo.txt' , './tests/test_dosestrellas.txt', './tests/instagram_famosos_grafo.txt', './tests/test_30_segundos.txt']  # Reemplaza con los nombres de tus archivos de grafo
parametro_p = 0.85 

# me armo lista svacias para pondes despues lo datos que me genere y asi poder graficarlos 
ranking_ejecucion = []
tamanos_grafos = []

for archivo_grafo in archivos_grafos:
    
    W = leer_archivo(archivo_grafo)
    
    x = medir_tiempo_ejecucion(W, parametro_p)
    
    ranking_ejecucion.append(x)
    tamanos_grafos.append(W.shape[0]) 

plt.figure(figsize=(10, 6))
plt.loglog(tamanos_grafos, ranking_ejecucion, marker='o', linestyle='-')
plt.title('Tiempos de ejecución de PageRank en función del tamaño del grafo')
plt.xlabel('Tamaño del grafo (número de nodos)')
plt.ylabel('Tiempo de ejecución (segundos)')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import time 
from funciones import *

    
# pongo todos los grafos juntos 
archivos_grafos = ['./tests/test_aleatorio.txt','./tests/mathworld_grafo.txt' , './tests/test_dosestrellas.txt', './tests/instagram_famosos_grafo.txt', './tests/test_30_segundos.txt']  # Reemplaza con los nombres de tus archivos de grafo
parametro_p = 0.85 

# me armo lista svacias para pondes despues lo datos que me genere y asi poder graficarlos 
ranking_ejecucion = []
tamanos_grafos = []

for archivo_grafo in archivos_grafos:
    
    W = leer_archivo(archivo_grafo)
    
    x = medir_tiempo_ejecucion(W, parametro_p)
    
    ranking_ejecucion.append(x)
    tamanos_grafos.append(W.shape[0]) 

plt.figure(figsize=(10, 6))
plt.loglog(tamanos_grafos, ranking_ejecucion, marker='o', linestyle='-', color='red')
plt.title('Tiempos de ejecución de PageRank en función del tamaño del grafo')
plt.xlabel('Tamaño del grafo (número de nodos)')
plt.ylabel('Tiempo de ejecución (segundos)')
plt.grid(True)

# Add labels to each point with scientific notation
for i, (x, y) in enumerate(zip(tamanos_grafos, ranking_ejecucion)):
    plt.annotate(f'({x}, {y:.3e})', (x, y), textcoords="offset points", xytext=(0,10), ha='center', bbox=dict(boxstyle='round', facecolor='white', edgecolor='gray'))

# Set scientific notation for the axis labels
#plt.ticklabel_format(style='sci', axis='both', scilimits=(0,0))


plt.show()

# %%
import matplotlib.pyplot as plt
import time 
from funciones import *
import adjustText

def medir_tiempo_ejecucion(W, p):
    start_time = time.time()
    calcularRanking(W, p)
    end_time = time.time()
    return end_time - start_time

    
# pongo todos los grafos juntos 
archivos_grafos = ['./tests/test_aleatorio.txt','./tests/mathworld_grafo.txt' , './tests/test_dosestrellas.txt', './tests/instagram_famosos_grafo.txt', './tests/test_30_segundos.txt']  # Reemplaza con los nombres de tus archivos de grafo
parametro_p = 0.85 

# me armo lista svacias para pondes despues lo datos que me genere y asi poder graficarlos 
tiempos_ejecucion = []
tamanos_grafos = []

for archivo_grafo in archivos_grafos:
    
    W = leer_archivo(archivo_grafo)
    
    tiempo = medir_tiempo_ejecucion(W, parametro_p)
    
    tiempos_ejecucion.append(tiempo)
    tamanos_grafos.append(W.shape[0]) 

plt.figure(figsize=(10, 6))
plt.loglog(tamanos_grafos, tiempos_ejecucion, marker='o', linestyle='-', color='red')
plt.title('Tiempos de ejecución de PageRank en función del tamaño del grafo')
plt.xlabel('Tamaño del grafo (número de nodos)')
plt.ylabel('Tiempo de ejecución (segundos)')
plt.grid(True)

# Add labels to each point with scientific notation
for i, (x, y) in enumerate(zip(tamanos_grafos, tiempos_ejecucion)):
    plt.annotate(f'({x}, {y:.3e})', (x, y), textcoords="offset points", xytext=(0,20), ha='center', bbox=dict(boxstyle='round', facecolor='white', edgecolor='gray'))

# Adjust text labels to avoid overlap
adjust_text(texts, arrowprops=dict(arrowstyle="->", color='gray', lw=0.5))

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_9571/1304695499.py in <module>
#       2 import time
#       3 from funciones import *
# ----> 4 import adjustText
#       5
#       6 def medir_tiempo_ejecucion(W, p):
#
# ModuleNotFoundError: No module named 'adjustText'

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

archivos_grafos = ['./tests/test_aleatorio.txt','./tests/mathworld_grafo.txt' , './tests/test_dosestrellas.txt', './tests/instagram_famosos_grafo.txt', './tests/test_30_segundos.txt']  # Reemplaza con los nombres de tus archivos de grafo

# Define function to read graph files and calculate ranking
def f(p_values, tamanos_grafos):
    results = []  # List to store results for each combination
    for p in p_values:
        for tamano in tamanos_grafos:
            index = tamanos_grafos.index(tamano)  # Get the index for the current tamano
            W = leer_archivo(archivos_grafos[index])  # Read the matrix for this index
            _, result = calcularRanking(W, p)  # Calculate the result
            results.append(result.max())  # Append the maximum ranking to the list
    return results

# Define values for parameter p
p = np.linspace(0, 1, 7)[1:6]

# Define list of graph files
archivos_grafos = ['./tests/test_aleatorio.txt', './tests/mathworld_grafo.txt', './tests/test_dosestrellas.txt', './tests/instagram_famosos_grafo.txt']

# Define parameter p
parametro_p = 0.85

# Get sizes of graphs
tamanos_grafos = [leer_archivo(archivo_grafo).shape[0] for archivo_grafo in archivos_grafos]

# Calculate rankings
X = f(p, tamanos_grafos)

# Create meshgrid for plotting
P, T = np.meshgrid(p, tamanos_grafos)

# Plot the 3D surface
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(P, T, np.array(X).reshape(P.shape), cmap='viridis')

# Set labels and title
ax.set_xlabel('p')
ax.set_ylabel('Number of Nodes')
ax.set_zlabel('Ranking')
ax.set_title('3D Plot of Ranking vs p and Number of Nodes')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the function f(x, y)
def f(x, y):
    return np.sin(np.pi * x) * np.cos(np.pi * y)

# Create a meshgrid of x and y values
x = np.linspace(0, 1, 100)
y = np.linspace(0, 1, 100)
X, Y = np.meshgrid(x, y)

# Evaluate the function f(x, y) for each combination of x and y
X = f(X, Y)

# Plot the 3D surface
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, X, cmap='viridis')

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Plot of f(x, y)')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define function to read graph files and calculate ranking
def f(p_values, archivo):
    x1 = []  # List to store results for each combination
    x2=[]
    x3=[]
    for p in p_values:
            W = leer_archivo(archivo)  # Read the matrix for this index
            _, result = calcularRanking(W, p)  # Calculate the result
            x1.append(result.max())  # Append the maximum ranking to the list
            result -= [result.max()]
            x2.append((result).max())
            result -= [result.max()]
            x3.append((result).max())
    return x1, x2, x3

print("f(0,5, test aleatorio)", f(0.5, './tests/test_aleatorio.txt'))

# Define values for parameter p
p = np.linspace(0, 1, 7)[1:6]

# Define list of graph files
archivos_grafos = ['./tests/test_aleatorio.txt', './tests/mathworld_grafo.txt', './tests/test_dosestrellas.txt', './tests/instagram_famosos_grafo.txt']

# Define parameter p
parametro_p = 0.85

# Get sizes of graphs
tamanos_grafos = [leer_archivo(archivo_grafo).shape[0] for archivo_grafo in archivos_grafos]

# Calculate rankings
X = f(p, tamanos_grafos)

# Create meshgrid for plotting
P, T = np.meshgrid(p, tamanos_grafos)

# Plot the 3D surface
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(P, T, np.array(X).reshape(P.shape), cmap='viridis')

# Set labels and title
ax.set_xlabel('p')
ax.set_ylabel('Number of Nodes')
ax.set_zlabel('Ranking')
ax.set_title('3D Plot of Ranking vs p and Number of Nodes')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_9571/3076634860.py in <module>
#      18     return x1, x2, x3
#      19
# ---> 20 print("f(0,5, test aleatorio)", f(0.5, './tests/test_aleatorio.txt'))
#      21
#      22 # Define values for parameter p
#
# /tmp/ipykernel_9571/3076634860.py in f(p_values, archivo)
#       8     x2=[]
#       9     x3=[]
# ---> 10     for p in p_values:
#      11             W = leer_archivo(archivo)  # Read the matrix for this index
#      12             _, result = calcularRanking(W, p)  # Calculate the result
#
# TypeError: 'float' object is not iterable

# %%
def f(p_values, archivo):
    x1 = []  # List to store top 3 maximum rankings for each p
    x2 = []
    x3 = []
    for p in p_values:
        W = leer_archivo(archivo)  # Read the matrix for this index
        _, result = calcularRanking(W, p)  # Calculate the result
        sorted_results = sorted(result, reverse=True)  # Sort the results in descending order
        top3 = sorted_results[:3]  # Select the top 3 maximum values
        x1.append(top3[0])  # Append the top 3 maximum values to the lists x1, x2, x3
        x2.append(top3[1])
        x3.append(top3[2])
    return x1, x2, x3

# %%
import matplotlib.pyplot as plt
import time 
from funciones import *

    
# pongo todos los grafos juntos 
archivos_grafos = ['./tests/mathworld_grafo.txt' , './tests/test_dosestrellas.txt', './tests/instagram_famosos_grafo.txt', './tests/test_30_segundos.txt']  # Reemplaza con los nombres de tus archivos de grafo
parametro_p = 0.85 

# me armo lista svacias para pondes despues lo datos que me genere y asi poder graficarlos 
ranking_ejecucion = []
tamanos_grafos = []

#for archivo_grafo in archivos_grafos:
    
W = leer_archivo('./tests/test_aleatorio.txt')
    
dibujarGrafo(W, print_ejes=False)

# %%
import matplotlib.pyplot as plt
import time 
from funciones import *

    
# pongo todos los grafos juntos 
archivos_grafos = [ './tests/test_dosestrellas.txt', './tests/instagram_famosos_grafo.txt', './tests/test_30_segundos.txt']  # Reemplaza con los nombres de tus archivos de grafo
parametro_p = 0.85 

# me armo lista svacias para pondes despues lo datos que me genere y asi poder graficarlos 
ranking_ejecucion = []
tamanos_grafos = []

#for archivo_grafo in archivos_grafos:
    
W = leer_archivo('./tests/mathworld_grafo.txt' )
    
dibujarGrafo(W, print_ejes=False)

# %%
import matplotlib.pyplot as plt
import time 
from funciones import *

    
# pongo todos los grafos juntos 
archivos_grafos = [ './tests/instagram_famosos_grafo.txt', './tests/test_30_segundos.txt']  # Reemplaza con los nombres de tus archivos de grafo
parametro_p = 0.85 

# me armo lista svacias para pondes despues lo datos que me genere y asi poder graficarlos 
ranking_ejecucion = []
tamanos_grafos = []

#for archivo_grafo in archivos_grafos:
    
W = leer_archivo('./tests/test_dosestrellas.txt' )
    
dibujarGrafo(W, print_ejes=False)

# %%
import matplotlib.pyplot as plt
import time 
from funciones import *

    
# pongo todos los grafos juntos 
archivos_grafos = [  './tests/test_30_segundos.txt']  # Reemplaza con los nombres de tus archivos de grafo
parametro_p = 0.85 

# me armo lista svacias para pondes despues lo datos que me genere y asi poder graficarlos 
ranking_ejecucion = []
tamanos_grafos = []

#for archivo_grafo in archivos_grafos:
    
W = leer_archivo('./tests/instagram_famosos_grafo.txt')
    
dibujarGrafo(W, print_ejes=False)

# %%
import matplotlib.pyplot as plt
import time 
from funciones import *

    
# pongo todos los grafos juntos 
archivos_grafos = [  ]  # Reemplaza con los nombres de tus archivos de grafo
parametro_p = 0.85 

# me armo lista svacias para pondes despues lo datos que me genere y asi poder graficarlos 
ranking_ejecucion = []
tamanos_grafos = []

#for archivo_grafo in archivos_grafos:
    
W = leer_archivo('./tests/test_30_segundos.txt')
    
dibujarGrafo(W, print_ejes=False)
